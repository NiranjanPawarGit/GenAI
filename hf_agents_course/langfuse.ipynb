# %%
# %pip install langfuse smolagents[telemetry] openinference-instrumentation-smolagents datasets smolagents[gradio] gradio --upgrade
# Out:
# Collecting langfuse
#   Downloading langfuse-3.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting openinference-instrumentation-smolagents
#   Downloading openinference_instrumentation_smolagents-0.1.14-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: datasets in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (4.0.0)
# Requirement already satisfied: gradio in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (5.38.2)
# Collecting gradio
#   Downloading gradio-5.41.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: smolagents[telemetry] in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (1.20.0)
# Collecting smolagents[telemetry]
#   Downloading smolagents-1.21.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from langfuse) (2.2.1)
# Requirement already satisfied: httpx<1.0,>=0.15.4 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from langfuse) (0.28.1)
# Collecting opentelemetry-api<2.0.0,>=1.33.1 (from langfuse)
#   Using cached opentelemetry_api-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp<2.0.0,>=1.33.1 (from langfuse)
#   Downloading opentelemetry_exporter_otlp-1.36.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk<2.0.0,>=1.33.1 (from langfuse)
#   Using cached opentelemetry_sdk-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26.0,>=23.2 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from langfuse) (25.0)
# Requirement already satisfied: pydantic<3.0,>=1.10.7 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from langfuse) (2.11.7)
# Requirement already satisfied: requests<3,>=2 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from langfuse) (2.32.4)
# Requirement already satisfied: wrapt<2.0,>=1.14 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from langfuse) (1.17.0)
# Requirement already satisfied: anyio in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from httpx<1.0,>=0.15.4->langfuse) (4.8.0)
# Requirement already satisfied: certifi in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from httpx<1.0,>=0.15.4->langfuse) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from httpx<1.0,>=0.15.4->langfuse) (1.0.9)
# Requirement already satisfied: idna in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from httpx<1.0,>=0.15.4->langfuse) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.15.4->langfuse) (0.16.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-api<2.0.0,>=1.33.1->langfuse) (8.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-api<2.0.0,>=1.33.1->langfuse) (4.14.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.33.1->langfuse) (3.23.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.36.0 (from opentelemetry-exporter-otlp<2.0.0,>=1.33.1->langfuse)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.36.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.36.0 (from opentelemetry-exporter-otlp<2.0.0,>=1.33.1->langfuse)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.36.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.36.0->opentelemetry-exporter-otlp<2.0.0,>=1.33.1->langfuse) (1.63.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.36.0->opentelemetry-exporter-otlp<2.0.0,>=1.33.1->langfuse) (1.68.1)
# Collecting opentelemetry-exporter-otlp-proto-common==1.36.0 (from opentelemetry-exporter-otlp-proto-grpc==1.36.0->opentelemetry-exporter-otlp<2.0.0,>=1.33.1->langfuse)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.36.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.36.0 (from opentelemetry-exporter-otlp-proto-grpc==1.36.0->opentelemetry-exporter-otlp<2.0.0,>=1.33.1->langfuse)
#   Using cached opentelemetry_proto-1.36.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf<7.0,>=5.0 (from opentelemetry-proto==1.36.0->opentelemetry-exporter-otlp-proto-grpc==1.36.0->opentelemetry-exporter-otlp<2.0.0,>=1.33.1->langfuse)
#   Using cached protobuf-6.31.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
#   Downloading protobuf-5.29.5-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting opentelemetry-semantic-conventions==0.57b0 (from opentelemetry-sdk<2.0.0,>=1.33.1->langfuse)
#   Using cached opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0,>=1.10.7->langfuse) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0,>=1.10.7->langfuse) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0,>=1.10.7->langfuse) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langfuse) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langfuse) (2.5.0)
# Requirement already satisfied: huggingface-hub>=0.31.2 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from smolagents[telemetry]) (0.34.3)
# Requirement already satisfied: rich>=13.9.4 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from smolagents[telemetry]) (14.1.0)
# Requirement already satisfied: jinja2>=3.1.4 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from smolagents[telemetry]) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from smolagents[telemetry]) (11.3.0)
# Requirement already satisfied: python-dotenv in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from smolagents[telemetry]) (1.1.1)
# Collecting arize-phoenix (from smolagents[telemetry])
#   Downloading arize_phoenix-11.20.0-py3-none-any.whl.metadata (30 kB)
# Collecting openinference-instrumentation>=0.1.27 (from openinference-instrumentation-smolagents)
#   Downloading openinference_instrumentation-0.1.37-py3-none-any.whl.metadata (4.9 kB)
# Collecting openinference-semantic-conventions>=0.1.17 (from openinference-instrumentation-smolagents)
#   Downloading openinference_semantic_conventions-0.1.21-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: opentelemetry-instrumentation in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from openinference-instrumentation-smolagents) (0.48b0)
# Requirement already satisfied: filelock in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from datasets) (2.2.6)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from datasets) (2.3.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.115.8)
# Requirement already satisfied: ffmpy in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.6.1)
# Requirement already satisfied: gradio-client==1.11.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (1.11.0)
# Requirement already satisfied: groovy~=0.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (3.11.1)
# Requirement already satisfied: pydub in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.12.5)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.45.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.16.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.34.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from gradio-client==1.11.0->gradio) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\niran\appdata\roaming\python\python310\site-packages (from anyio->httpx<1.0,>=0.15.4->langfuse) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from anyio->httpx<1.0,>=0.15.4->langfuse) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: colorama in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from rich>=13.9.4->smolagents[telemetry]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from rich>=13.9.4->smolagents[telemetry]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents[telemetry]) (0.1.2)
# Collecting aioitertools (from arize-phoenix->smolagents[telemetry])
#   Downloading aioitertools-0.12.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: aiosqlite in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (0.21.0)
# Collecting alembic<2,>=1.3.0 (from arize-phoenix->smolagents[telemetry])
#   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting arize-phoenix-client (from arize-phoenix->smolagents[telemetry])
#   Downloading arize_phoenix_client-1.14.2-py3-none-any.whl.metadata (4.4 kB)
# Collecting arize-phoenix-evals>=0.20.6 (from arize-phoenix->smolagents[telemetry])
#   Downloading arize_phoenix_evals-0.26.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting arize-phoenix-otel>=0.10.3 (from arize-phoenix->smolagents[telemetry])
#   Downloading arize_phoenix_otel-0.12.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting authlib (from arize-phoenix->smolagents[telemetry])
#   Downloading authlib-1.6.1-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cachetools in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (5.5.0)
# Collecting email-validator (from arize-phoenix->smolagents[telemetry])
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting grpc-interceptor (from arize-phoenix->smolagents[telemetry])
#   Downloading grpc_interceptor-0.15.4-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: prometheus-client in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (0.22.1)
# Requirement already satisfied: psutil in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (7.0.0)
# Requirement already satisfied: scikit-learn in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (1.6.0)
# Requirement already satisfied: scipy in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (1.14.1)
# Requirement already satisfied: sqlalchemy<3,>=2.0.4 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy[asyncio]<3,>=2.0.4->arize-phoenix->smolagents[telemetry]) (2.0.41)
# Collecting sqlean-py>=3.45.1 (from arize-phoenix->smolagents[telemetry])
#   Downloading sqlean_py-3.49.1-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# Collecting strawberry-graphql==0.270.1 (from arize-phoenix->smolagents[telemetry])
#   Downloading strawberry_graphql-0.270.1-py3-none-any.whl.metadata (7.7 kB)
# Collecting wrapt<2.0,>=1.14 (from langfuse)
#   Downloading wrapt-1.17.2-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Collecting graphql-core<3.4.0,>=3.2.0 (from strawberry-graphql==0.270.1->arize-phoenix->smolagents[telemetry])
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting Mako (from alembic<2,>=1.3.0->arize-phoenix->smolagents[telemetry])
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: tomli in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from alembic<2,>=1.3.0->arize-phoenix->smolagents[telemetry]) (2.2.1)
# Requirement already satisfied: greenlet>=1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy<3,>=2.0.4->sqlalchemy[asyncio]<3,>=2.0.4->arize-phoenix->smolagents[telemetry]) (3.2.3)
# Collecting pystache (from arize-phoenix-evals>=0.20.6->arize-phoenix->smolagents[telemetry])
#   Downloading pystache-0.6.8-py3-none-any.whl.metadata (14 kB)
# Collecting cryptography (from authlib->arize-phoenix->smolagents[telemetry])
#   Downloading cryptography-45.0.6-cp37-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: cffi>=1.14 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from cryptography->authlib->arize-phoenix->smolagents[telemetry]) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.14->cryptography->authlib->arize-phoenix->smolagents[telemetry]) (2.22)
# Collecting dnspython>=2.0.0 (from email-validator->arize-phoenix->smolagents[telemetry])
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: setuptools>=16.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation->openinference-instrumentation-smolagents) (80.9.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->arize-phoenix->smolagents[telemetry]) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->arize-phoenix->smolagents[telemetry]) (3.5.0)
# Downloading langfuse-3.2.2-py3-none-any.whl (299 kB)
# Using cached opentelemetry_api-1.36.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_exporter_otlp-1.36.0-py3-none-any.whl (7.0 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.36.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.36.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_http-1.36.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.36.0-py3-none-any.whl (72 kB)
# Using cached opentelemetry_sdk-1.36.0-py3-none-any.whl (119 kB)
# Using cached opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl (201 kB)
# Downloading protobuf-5.29.5-cp310-abi3-win_amd64.whl (434 kB)
# Downloading smolagents-1.21.0-py3-none-any.whl (145 kB)
# Downloading openinference_instrumentation_smolagents-0.1.14-py3-none-any.whl (12 kB)
# Downloading gradio-5.41.1-py3-none-any.whl (59.7 MB)
#    ---------------------------------------- 0.0/59.7 MB ? eta -:--:--
#     --------------------------------------- 0.8/59.7 MB 4.8 MB/s eta 0:00:13
#    - -------------------------------------- 1.6/59.7 MB 4.2 MB/s eta 0:00:14
#    - -------------------------------------- 2.6/59.7 MB 4.3 MB/s eta 0:00:14
#    -- ------------------------------------- 3.1/59.7 MB 4.3 MB/s eta 0:00:14
#    -- ------------------------------------- 4.2/59.7 MB 4.1 MB/s eta 0:00:14
#    --- ------------------------------------ 5.2/59.7 MB 4.2 MB/s eta 0:00:13
#    ---- ----------------------------------- 6.3/59.7 MB 4.4 MB/s eta 0:00:13
#    ---- ----------------------------------- 7.3/59.7 MB 4.5 MB/s eta 0:00:12
#    ----- ---------------------------------- 8.4/59.7 MB 4.6 MB/s eta 0:00:12
#    ----- ---------------------------------- 8.9/59.7 MB 4.4 MB/s eta 0:00:12
#    ------ --------------------------------- 9.7/59.7 MB 4.4 MB/s eta 0:00:12
#    ------- -------------------------------- 10.7/59.7 MB 4.4 MB/s eta 0:00:12
#    ------- -------------------------------- 11.5/59.7 MB 4.4 MB/s eta 0:00:11
#    -------- ------------------------------- 13.1/59.7 MB 4.5 MB/s eta 0:00:11
#    --------- ------------------------------ 14.2/59.7 MB 4.6 MB/s eta 0:00:10
#    ---------- ----------------------------- 14.9/59.7 MB 4.6 MB/s eta 0:00:10
#    ---------- ----------------------------- 16.3/59.7 MB 4.6 MB/s eta 0:00:10
#    ----------- ---------------------------- 17.3/59.7 MB 4.7 MB/s eta 0:00:10
#    ------------ --------------------------- 18.6/59.7 MB 4.8 MB/s eta 0:00:09
#    ------------- -------------------------- 19.9/59.7 MB 4.8 MB/s eta 0:00:09
#    -------------- ------------------------- 21.0/59.7 MB 4.8 MB/s eta 0:00:09
#    -------------- ------------------------- 22.0/59.7 MB 4.8 MB/s eta 0:00:08
#    --------------- ------------------------ 23.1/59.7 MB 4.9 MB/s eta 0:00:08
#    --------------- ------------------------ 23.6/59.7 MB 4.8 MB/s eta 0:00:08
#    ---------------- ----------------------- 24.6/59.7 MB 4.8 MB/s eta 0:00:08
#    ----------------- ---------------------- 25.4/59.7 MB 4.8 MB/s eta 0:00:08
#    ----------------- ---------------------- 26.5/59.7 MB 4.8 MB/s eta 0:00:07
#    ------------------ --------------------- 27.8/59.7 MB 4.8 MB/s eta 0:00:07
#    ------------------- -------------------- 28.8/59.7 MB 4.8 MB/s eta 0:00:07
#    -------------------- ------------------- 29.9/59.7 MB 4.8 MB/s eta 0:00:07
#    -------------------- ------------------- 30.9/59.7 MB 4.8 MB/s eta 0:00:06
#    --------------------- ------------------ 32.2/59.7 MB 4.9 MB/s eta 0:00:06
#    ---------------------- ----------------- 33.6/59.7 MB 4.9 MB/s eta 0:00:06
#    ----------------------- ---------------- 34.3/59.7 MB 4.9 MB/s eta 0:00:06
#    ----------------------- ---------------- 35.7/59.7 MB 4.9 MB/s eta 0:00:05
#    ------------------------ --------------- 36.7/59.7 MB 4.9 MB/s eta 0:00:05
#    ------------------------- -------------- 37.7/59.7 MB 5.0 MB/s eta 0:00:05
#    -------------------------- ------------- 38.8/59.7 MB 5.0 MB/s eta 0:00:05
#    -------------------------- ------------- 39.8/59.7 MB 5.0 MB/s eta 0:00:05
#    --------------------------- ------------ 40.4/59.7 MB 4.9 MB/s eta 0:00:04
#    --------------------------- ------------ 41.2/59.7 MB 4.9 MB/s eta 0:00:04
#    ---------------------------- ----------- 41.9/59.7 MB 4.9 MB/s eta 0:00:04
#    ---------------------------- ----------- 42.7/59.7 MB 4.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 43.5/59.7 MB 4.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 44.3/59.7 MB 4.8 MB/s eta 0:00:04
#    ------------------------------ --------- 44.8/59.7 MB 4.8 MB/s eta 0:00:04
#    ------------------------------ --------- 45.6/59.7 MB 4.7 MB/s eta 0:00:03
#    ------------------------------- -------- 46.7/59.7 MB 4.7 MB/s eta 0:00:03
#    ------------------------------- -------- 47.7/59.7 MB 4.7 MB/s eta 0:00:03
#    -------------------------------- ------- 48.8/59.7 MB 4.7 MB/s eta 0:00:03
#    --------------------------------- ------ 50.3/59.7 MB 4.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 51.4/59.7 MB 4.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 52.7/59.7 MB 4.8 MB/s eta 0:00:02
#    ------------------------------------ --- 54.0/59.7 MB 4.9 MB/s eta 0:00:02
#    ------------------------------------- -- 55.3/59.7 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------- -- 56.6/59.7 MB 4.9 MB/s eta 0:00:01
#    -------------------------------------- - 57.7/59.7 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  58.7/59.7 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  59.5/59.7 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 59.7/59.7 MB 4.9 MB/s eta 0:00:00
# Downloading openinference_instrumentation-0.1.37-py3-none-any.whl (28 kB)
# Downloading openinference_semantic_conventions-0.1.21-py3-none-any.whl (10 kB)
# Downloading arize_phoenix-11.20.0-py3-none-any.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.4 MB 6.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.3/2.4 MB 3.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.4 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.4 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 2.2 MB/s eta 0:00:00
# Downloading strawberry_graphql-0.270.1-py3-none-any.whl (301 kB)
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Downloading wrapt-1.17.2-cp310-cp310-win_amd64.whl (38 kB)
# Downloading arize_phoenix_evals-0.26.1-py3-none-any.whl (93 kB)
# Downloading arize_phoenix_otel-0.12.1-py3-none-any.whl (13 kB)
# Downloading sqlean_py-3.49.1-cp310-cp310-win_amd64.whl (803 kB)
#    ---------------------------------------- 0.0/803.5 kB ? eta -:--:--
#    ---------------------------------------- 803.5/803.5 kB 4.3 MB/s eta 0:00:00
# Downloading aioitertools-0.12.0-py3-none-any.whl (24 kB)
# Downloading arize_phoenix_client-1.14.2-py3-none-any.whl (100 kB)
# Downloading authlib-1.6.1-py2.py3-none-any.whl (239 kB)
# Downloading cryptography-45.0.6-cp37-abi3-win_amd64.whl (3.4 MB)
#    ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#    ------------ --------------------------- 1.0/3.4 MB 5.6 MB/s eta 0:00:01
#    --------------------------- ------------ 2.4/3.4 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------- -- 3.1/3.4 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.4/3.4 MB 5.6 MB/s eta 0:00:00
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Downloading grpc_interceptor-0.15.4-py3-none-any.whl (20 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading pystache-0.6.8-py3-none-any.whl (82 kB)
# Installing collected packages: wrapt, sqlean-py, pystache, protobuf, openinference-semantic-conventions, Mako, grpc-interceptor, graphql-core, dnspython, aioitertools, strawberry-graphql, opentelemetry-proto, opentelemetry-api, email-validator, cryptography, alembic, smolagents, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, authlib, arize-phoenix-evals, opentelemetry-sdk, gradio, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, openinference-instrumentation, opentelemetry-exporter-otlp, openinference-instrumentation-smolagents, langfuse, arize-phoenix-otel, arize-phoenix-client, arize-phoenix
#
#   Attempting uninstall: wrapt
#
#     Found existing installation: wrapt 1.17.0
#
#     Uninstalling wrapt-1.17.0:
#
#       Successfully uninstalled wrapt-1.17.0
#
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    -- -------------------------------------  2/32 [pystache]
#    -- -------------------------------------  2/32 [pystache]
#    -- -------------------------------------  2/32 [pystache]
#    -- -------------------------------------  2/32 [pystache]
#    -- -------------------------------------  2/32 [pystache]
#    -- -------------------------------------  2/32 [pystache]
#   Attempting uninstall: protobuf
#    -- -------------------------------------  2/32 [pystache]
#     Found existing installation: protobuf 3.19.6
#    -- -------------------------------------  2/32 [pystache]
#     Uninstalling protobuf-3.19.6:
#    -- -------------------------------------  2/32 [pystache]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#       Successfully uninstalled protobuf-3.19.6
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    --- ------------------------------------  3/32 [protobuf]
#    ---- ----------------------------  4/32 [openinference-semantic-conventions]
#    ------ ---------------------------------  5/32 [Mako]
#    ------ ---------------------------------  5/32 [Mako]
#    ------ ---------------------------------  5/32 [Mako]
#    ------- --------------------------------  6/32 [grpc-interceptor]
#    -------- -------------------------------  7/32 [graphql-core]
#    -------- -------------------------------  7/32 [graphql-core]
#    -------- -------------------------------  7/32 [graphql-core]
#    -------- -------------------------------  7/32 [graphql-core]
#    -------- -------------------------------  7/32 [graphql-core]
#    -------- -------------------------------  7/32 [graphql-core]
#    -------- -------------------------------  7/32 [graphql-core]
#    -------- -------------------------------  7/32 [graphql-core]
#    -------- -------------------------------  7/32 [graphql-core]
#    ---------- -----------------------------  8/32 [dnspython]
#    ---------- -----------------------------  8/32 [dnspython]
#    ---------- -----------------------------  8/32 [dnspython]
#    ---------- -----------------------------  8/32 [dnspython]
#    ---------- -----------------------------  8/32 [dnspython]
#    ---------- -----------------------------  8/32 [dnspython]
#    ---------- -----------------------------  8/32 [dnspython]
#    ---------- -----------------------------  8/32 [dnspython]
#    ---------- -----------------------------  8/32 [dnspython]
#    ---------- -----------------------------  8/32 [dnspython]
#    ---------- -----------------------------  8/32 [dnspython]
#    ---------- -----------------------------  8/32 [dnspython]
#    ----------- ----------------------------  9/32 [aioitertools]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#   Attempting uninstall: opentelemetry-proto
#    ------------ --------------------------- 10/32 [strawberry-graphql]
#    ------------- -------------------------- 11/32 [opentelemetry-proto]
#     Found existing installation: opentelemetry-proto 1.27.0
#    ------------- -------------------------- 11/32 [opentelemetry-proto]
#     Uninstalling opentelemetry-proto-1.27.0:
#    ------------- -------------------------- 11/32 [opentelemetry-proto]
#       Successfully uninstalled opentelemetry-proto-1.27.0
#    ------------- -------------------------- 11/32 [opentelemetry-proto]
#    ------------- -------------------------- 11/32 [opentelemetry-proto]
#    ------------- -------------------------- 11/32 [opentelemetry-proto]
#   Attempting uninstall: opentelemetry-api
#    ------------- -------------------------- 11/32 [opentelemetry-proto]
#     Found existing installation: opentelemetry-api 1.27.0
#    ------------- -------------------------- 11/32 [opentelemetry-proto]
#    --------------- ------------------------ 12/32 [opentelemetry-api]
#     Uninstalling opentelemetry-api-1.27.0:
#    --------------- ------------------------ 12/32 [opentelemetry-api]
#       Successfully uninstalled opentelemetry-api-1.27.0
#    --------------- ------------------------ 12/32 [opentelemetry-api]
#    --------------- ------------------------ 12/32 [opentelemetry-api]
#    --------------- ------------------------ 12/32 [opentelemetry-api]
#    --------------- ------------------------ 12/32 [opentelemetry-api]
#    ---------------- ----------------------- 13/32 [email-validator]
#    ----------------- ---------------------- 14/32 [cryptography]
#    ----------------- ---------------------- 14/32 [cryptography]
#    ----------------- ---------------------- 14/32 [cryptography]
#    ----------------- ---------------------- 14/32 [cryptography]
#    ----------------- ---------------------- 14/32 [cryptography]
#    ----------------- ---------------------- 14/32 [cryptography]
#    ------------------ --------------------- 15/32 [alembic]
#    ------------------ --------------------- 15/32 [alembic]
#    ------------------ --------------------- 15/32 [alembic]
#    ------------------ --------------------- 15/32 [alembic]
#    ------------------ --------------------- 15/32 [alembic]
#    ------------------ --------------------- 15/32 [alembic]
#    ------------------ --------------------- 15/32 [alembic]
#   Attempting uninstall: smolagents
#    ------------------ --------------------- 15/32 [alembic]
#     Found existing installation: smolagents 1.20.0
#    ------------------ --------------------- 15/32 [alembic]
#     Uninstalling smolagents-1.20.0:
#    ------------------ --------------------- 15/32 [alembic]
#       Successfully uninstalled smolagents-1.20.0
#    ------------------ --------------------- 15/32 [alembic]
#    -------------------- ------------------- 16/32 [smolagents]
#    -------------------- ------------------- 16/32 [smolagents]
#    -------------------- ------------------- 16/32 [smolagents]
#   Attempting uninstall: opentelemetry-semantic-conventions
#    -------------------- ------------------- 16/32 [smolagents]
#     Found existing installation: opentelemetry-semantic-conventions 0.48b0
#    -------------------- ------------------- 16/32 [smolagents]
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#     Uninstalling opentelemetry-semantic-conventions-0.48b0:
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#       Successfully uninstalled opentelemetry-semantic-conventions-0.48b0
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-common
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#     Found existing installation: opentelemetry-exporter-otlp-proto-common 1.27.0
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#     Uninstalling opentelemetry-exporter-otlp-proto-common-1.27.0:
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-common-1.27.0
#    ----------------- --------------- 17/32 [opentelemetry-semantic-conventions]
#    --------------- ----------- 18/32 [opentelemetry-exporter-otlp-proto-common]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ----------------------- ---------------- 19/32 [authlib]
#    ------------------------- -------------- 20/32 [arize-phoenix-evals]
#    ------------------------- -------------- 20/32 [arize-phoenix-evals]
#    ------------------------- -------------- 20/32 [arize-phoenix-evals]
#   Attempting uninstall: opentelemetry-sdk
#    ------------------------- -------------- 20/32 [arize-phoenix-evals]
#     Found existing installation: opentelemetry-sdk 1.27.0
#    ------------------------- -------------- 20/32 [arize-phoenix-evals]
#     Uninstalling opentelemetry-sdk-1.27.0:
#    ------------------------- -------------- 20/32 [arize-phoenix-evals]
#       Successfully uninstalled opentelemetry-sdk-1.27.0
#    ------------------------- -------------- 20/32 [arize-phoenix-evals]
#    -------------------------- ------------- 21/32 [opentelemetry-sdk]
#    -------------------------- ------------- 21/32 [opentelemetry-sdk]
#    -------------------------- ------------- 21/32 [opentelemetry-sdk]
#    -------------------------- ------------- 21/32 [opentelemetry-sdk]
#    -------------------------- ------------- 21/32 [opentelemetry-sdk]
#   Attempting uninstall: gradio
#    -------------------------- ------------- 21/32 [opentelemetry-sdk]
#     Found existing installation: gradio 5.38.2
#    -------------------------- ------------- 21/32 [opentelemetry-sdk]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#     Uninstalling gradio-5.38.2:
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#       Successfully uninstalled gradio-5.38.2
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------------- ------------ 22/32 [gradio]
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-grpc
#    --------------------------- ------------ 22/32 [gradio]
#     Found existing installation: opentelemetry-exporter-otlp-proto-grpc 1.27.0
#    --------------------------- ------------ 22/32 [gradio]
#     Uninstalling opentelemetry-exporter-otlp-proto-grpc-1.27.0:
#    --------------------------- ------------ 22/32 [gradio]
#    --------------------- ------- 24/32 [opentelemetry-exporter-otlp-proto-grpc]
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-grpc-1.27.0
#    --------------------- ------- 24/32 [opentelemetry-exporter-otlp-proto-grpc]
#    ----------------------------- -------- 25/32 [openinference-instrumentation]
#    ---------------------- ---- 27/32 [openinference-instrumentation-smolagents]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ----------------------------------- ---- 28/32 [langfuse]
#    ------------------------------------- -- 30/32 [arize-phoenix-client]
#    ------------------------------------- -- 30/32 [arize-phoenix-client]
#    ------------------------------------- -- 30/32 [arize-phoenix-client]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    -------------------------------------- - 31/32 [arize-phoenix]
#    ---------------------------------------- 32/32 [arize-phoenix]
#
# Successfully installed Mako-1.3.10 aioitertools-0.12.0 alembic-1.16.4 arize-phoenix-11.20.0 arize-phoenix-client-1.14.2 arize-phoenix-evals-0.26.1 arize-phoenix-otel-0.12.1 authlib-1.6.1 cryptography-45.0.6 dnspython-2.7.0 email-validator-2.2.0 gradio-5.41.1 graphql-core-3.2.6 grpc-interceptor-0.15.4 langfuse-3.2.2 openinference-instrumentation-0.1.37 openinference-instrumentation-smolagents-0.1.14 openinference-semantic-conventions-0.1.21 opentelemetry-api-1.36.0 opentelemetry-exporter-otlp-1.36.0 opentelemetry-exporter-otlp-proto-common-1.36.0 opentelemetry-exporter-otlp-proto-grpc-1.36.0 opentelemetry-exporter-otlp-proto-http-1.36.0 opentelemetry-proto-1.36.0 opentelemetry-sdk-1.36.0 opentelemetry-semantic-conventions-0.57b0 protobuf-5.29.5 pystache-0.6.8 smolagents-1.21.0 sqlean-py-3.49.1 strawberry-graphql-0.270.1 wrapt-1.17.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\niran\AppData\Local\Programs\Python\Python310\Lib\site-packages\~rapt'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-embeddings-openai 0.1.11 requires llama-index-core<0.11.0,>=0.10.1, but you have llama-index-core 0.13.0 which is incompatible.
# llama-index-indices-managed-llama-cloud 0.1.6 requires llama-index-core<0.11.0,>=0.10.0, but you have llama-index-core 0.13.0 which is incompatible.
# llama-index-llms-openai 0.1.31 requires llama-index-core<0.11.0,>=0.10.57, but you have llama-index-core 0.13.0 which is incompatible.
# llama-index-multi-modal-llms-openai 0.1.9 requires llama-index-core<0.11.0,>=0.10.1, but you have llama-index-core 0.13.0 which is incompatible.
# llama-index-program-openai 0.1.7 requires llama-index-core<0.11.0,>=0.10.57, but you have llama-index-core 0.13.0 which is incompatible.
# llama-index-question-gen-openai 0.1.3 requires llama-index-core<0.11.0,>=0.10.1, but you have llama-index-core 0.13.0 which is incompatible.
# llama-index-readers-file 0.1.33 requires llama-index-core<0.11.0,>=0.10.37.post1, but you have llama-index-core 0.13.0 which is incompatible.
# llama-index-readers-llama-parse 0.1.6 requires llama-index-core<0.11.0,>=0.10.7, but you have llama-index-core 0.13.0 which is incompatible.
# opentelemetry-instrumentation-asgi 0.48b0 requires opentelemetry-semantic-conventions==0.48b0, but you have opentelemetry-semantic-conventions 0.57b0 which is incompatible.
# opentelemetry-instrumentation-fastapi 0.48b0 requires opentelemetry-semantic-conventions==0.48b0, but you have opentelemetry-semantic-conventions 0.57b0 which is incompatible.
# tensorboard 2.10.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 5.29.5 which is incompatible.
# tensorflow 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 5.29.5 which is incompatible.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv

load_dotenv()
lf_secret = os.getenv("LANGFUSE_SECRET_KEY")
lf_public = os.getenv("LANGFUSE_PUBLIC_KEY")
lf_host = os.getenv("LANGFUSE_HOST")

# %%
print(lf_public)
# Out:
# pk-lf-0a9f8ea9-e5d6-4ebe-b77e-56371096caf3

# %%
from langfuse import get_client

langfuse = get_client()

if langfuse.auth_check():
    print("Langfuse is ready!")
else:
    print("Auth failed")
# Out:
# Langfuse is ready!

# %%
from openinference.instrumentation.smolagents import SmolagentsInstrumentor

SmolagentsInstrumentor().instrument()

# %%
# !pip install smolagents[litellm]
# Out:
# Collecting smolagents[litellm]
#   Using cached smolagents-1.21.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: huggingface-hub>=0.31.2 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from smolagents[litellm]) (0.34.3)
# Requirement already satisfied: requests>=2.32.3 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from smolagents[litellm]) (2.32.4)
# Requirement already satisfied: rich>=13.9.4 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from smolagents[litellm]) (14.1.0)
# Requirement already satisfied: jinja2>=3.1.4 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from smolagents[litellm]) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from smolagents[litellm]) (11.3.0)
# Requirement already satisfied: python-dotenv in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from smolagents[litellm]) (1.1.1)
# Collecting litellm>=1.60.2 (from smolagents[litellm])
#   Downloading litellm-1.75.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: filelock in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.31.2->smolagents[litellm]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.31.2->smolagents[litellm]) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.31.2->smolagents[litellm]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.31.2->smolagents[litellm]) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.31.2->smolagents[litellm]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.31.2->smolagents[litellm]) (4.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from jinja2>=3.1.4->smolagents[litellm]) (3.0.2)
# Requirement already satisfied: aiohttp>=3.10 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from litellm>=1.60.2->smolagents[litellm]) (3.12.15)
# Requirement already satisfied: click in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from litellm>=1.60.2->smolagents[litellm]) (8.1.8)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from litellm>=1.60.2->smolagents[litellm]) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from litellm>=1.60.2->smolagents[litellm]) (8.4.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from litellm>=1.60.2->smolagents[litellm]) (4.25.0)
# Requirement already satisfied: openai>=1.68.2 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from litellm>=1.60.2->smolagents[litellm]) (1.97.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from litellm>=1.60.2->smolagents[litellm]) (2.11.7)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from litellm>=1.60.2->smolagents[litellm]) (0.9.0)
# Requirement already satisfied: tokenizers in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from litellm>=1.60.2->smolagents[litellm]) (0.21.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.60.2->smolagents[litellm]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.60.2->smolagents[litellm]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.60.2->smolagents[litellm]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.60.2->smolagents[litellm]) (0.26.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.60.2->smolagents[litellm]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.60.2->smolagents[litellm]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.60.2->smolagents[litellm]) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (1.20.1)
# Requirement already satisfied: idna>=2.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (3.10)
# Requirement already satisfied: anyio in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (4.8.0)
# Requirement already satisfied: certifi in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (0.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=6.8.0->litellm>=1.60.2->smolagents[litellm]) (3.23.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from openai>=1.68.2->litellm>=1.60.2->smolagents[litellm]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from openai>=1.68.2->litellm>=1.60.2->smolagents[litellm]) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from openai>=1.68.2->litellm>=1.60.2->smolagents[litellm]) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\niran\appdata\roaming\python\python310\site-packages (from anyio->httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.32.3->smolagents[litellm]) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.32.3->smolagents[litellm]) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from rich>=13.9.4->smolagents[litellm]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from rich>=13.9.4->smolagents[litellm]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents[litellm]) (0.1.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from tiktoken>=0.7.0->litellm>=1.60.2->smolagents[litellm]) (2025.7.34)
# Requirement already satisfied: colorama in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.31.2->smolagents[litellm]) (0.4.6)
# Using cached smolagents-1.21.0-py3-none-any.whl (145 kB)
# Downloading litellm-1.75.0-py3-none-any.whl (8.9 MB)
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.9 MB 3.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/8.9 MB 3.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.3/8.9 MB 2.5 MB/s eta 0:00:04
#    -------- ------------------------------- 1.8/8.9 MB 2.2 MB/s eta 0:00:04
#    --------- ------------------------------ 2.1/8.9 MB 2.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.6/8.9 MB 2.3 MB/s eta 0:00:03
#    -------------- ------------------------- 3.1/8.9 MB 2.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.7/8.9 MB 2.3 MB/s eta 0:00:03
#    ------------------ --------------------- 4.2/8.9 MB 2.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.0/8.9 MB 2.5 MB/s eta 0:00:02
#    ------------------------ --------------- 5.5/8.9 MB 2.5 MB/s eta 0:00:02
#    --------------------------- ------------ 6.0/8.9 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 6.8/8.9 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 7.3/8.9 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 8.1/8.9 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.9 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 2.7 MB/s eta 0:00:00
# Installing collected packages: smolagents, litellm
#
#    ---------------------------------------- 0/2 [smolagents]
#    ---------------------------------------- 0/2 [smolagents]
#    ---------------------------------------- 0/2 [smolagents]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    -------------------- ------------------- 1/2 [litellm]
#    ---------------------------------------- 2/2 [litellm]
#
# Successfully installed litellm-1.75.0 smolagents-1.21.0
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from smolagents import CodeAgent
from smolagents.models import LiteLLMModel

model = LiteLLMModel(
    model_id="ollama/llama3",        # This is the format LiteLLM expects
    api_base="http://localhost:11434", 
    api_key=None                     # Ollama does not require an API key
)

agent = CodeAgent(
    tools = [],
    model=model
)

response = agent.run("1+1=?")
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ 1+1=?                                                                                                           │
# │                                                                                                                 │
# ╰─ LiteLLMModel - ollama/llama3 ──────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error in generating model output:
# 'LiteLLMModel' object has no attribute 'last_input_token_count'
# [Step 1: Duration 15.23 seconds]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\niran\AppData\Local\Programs\Python\Python310\lib\site-packages\smolagents\agents.py:1615, in CodeAgent._step_stream(self, memory_step)
#    1614 else:
# -> 1615     chat_message: ChatMessage = self.model.generate(
#    1616         input_messages,
#    1617         stop_sequences=stop_sequences,
#    1618         **additional_args,
#    1619     )
#    1620     memory_step.model_output_message = chat_message
#
# File c:\Users\niran\AppData\Local\Programs\Python\Python310\lib\site-packages\openinference\instrumentation\smolagents\_wrappers.py:313, in _ModelWrapper.__call__(self, wrapped, instance, args, kwargs)
#     312 span.set_status(trace_api.StatusCode.OK)
# --> 313 span.set_attribute(LLM_TOKEN_COUNT_PROMPT, model.last_input_token_count)
#     314 span.set_attribute(LLM_TOKEN_COUNT_COMPLETION, model.last_output_token_count)
#
# AttributeError: 'LiteLLMModel' object has no attribute 'last_input_token_count'
#
# The above exception was the direct cause of the following exception:
#
# AgentGenerationError                      Traceback (most recent call last)
# Cell In[16], line 15
#       4 model = LiteLLMModel(
#       5     model_id="ollama/llama3",        # This is the format LiteLLM expects
#       6     api_base="http://localhost:11434",
#       7     api_key=None                     # Ollama does not require an API key
#       8 )
#      10 agent = CodeAgent(
#      11     tools = [],
#      12     model=model
#      13 )
# ---> 15 response = agent.run("1+1=?")
#      16 print(response)
#
# File c:\Users\niran\AppData\Local\Programs\Python\Python310\lib\site-packages\openinference\instrumentation\smolagents\_wrappers.py:129, in _RunWrapper.__call__(self, wrapped, instance, args, kwargs)
#     111 arguments = _bind_arguments(wrapped, *args, **kwargs)
#     112 with self._tracer.start_as_current_span(
#     113     span_name,
#     114     attributes=dict(
#    (...)
#     127     ),
#     128 ) as span:
# --> 129     agent_output = wrapped(*args, **kwargs)
#     130     span.set_attribute(LLM_TOKEN_COUNT_PROMPT, agent.monitor.total_input_token_count)
#     131     span.set_attribute(LLM_TOKEN_COUNT_COMPLETION, agent.monitor.total_output_token_count)
#
# File c:\Users\niran\AppData\Local\Programs\Python\Python310\lib\site-packages\smolagents\agents.py:456, in MultiStepAgent.run(self, task, stream, reset, images, additional_args, max_steps)
#     453 run_start_time = time.time()
#     454 # Outputs are returned only at the end. We only look at the last step.
# --> 456 steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     457 assert isinstance(steps[-1], FinalAnswerStep)
#     458 output = steps[-1].output
#
# File c:\Users\niran\AppData\Local\Programs\Python\Python310\lib\site-packages\smolagents\agents.py:550, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     546             action_step.is_final_answer = True
#     548 except AgentGenerationError as e:
#     549     # Agent generation errors are not caused by a Model error but an implementation error: so we should raise them and exit.
# --> 550     raise e
#     551 except AgentError as e:
#     552     # Other AgentError types are caused by the Model, so we should log them and iterate.
#     553     action_step.error = e
#
# File c:\Users\niran\AppData\Local\Programs\Python\Python310\lib\site-packages\smolagents\agents.py:532, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     530 self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
#     531 try:
# --> 532     for output in self._step_stream(action_step):
#     533         # Yield all
#     534         yield output
#     536         if isinstance(output, ActionOutput) and output.is_final_answer:
#
# File c:\Users\niran\AppData\Local\Programs\Python\Python310\lib\site-packages\smolagents\agents.py:1638, in CodeAgent._step_stream(self, memory_step)
#    1636     memory_step.model_output = output_text
#    1637 except Exception as e:
# -> 1638     raise AgentGenerationError(f"Error in generating model output:\n{e}", self.logger) from e
#    1640 ### Parse output ###
#    1641 try:
#
# AgentGenerationError: Error in generating model output:
# 'LiteLLMModel' object has no attribute 'last_input_token_count'

# %%
# !pip install ddgs
# Out:
# Collecting ddgs
#   Downloading ddgs-9.5.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: click>=8.1.8 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from ddgs) (8.1.8)
# Requirement already satisfied: primp>=0.15.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from ddgs) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from ddgs) (6.0.0)
# Requirement already satisfied: colorama in c:\users\niran\appdata\local\programs\python\python310\lib\site-packages (from click>=8.1.8->ddgs) (0.4.6)
# Downloading ddgs-9.5.2-py3-none-any.whl (36 kB)
# Installing collected packages: ddgs
# Successfully installed ddgs-9.5.2
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from smolagents import (CodeAgent, DuckDuckGoSearchTool, InferenceClientModel)

search_tool = DuckDuckGoSearchTool()
agent = CodeAgent(tools=[search_tool], model=InferenceClientModel())

agent.run("How many Rubik's Cubes could you fit inside the Notre Dame Cathedral?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ How many Rubik's Cubes could you fit inside the Notre Dame Cathedral?                                           │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error in generating model output:
# 'InferenceClientModel' object has no attribute 'last_input_token_count'
# [Step 1: Duration 2.06 seconds]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\niran\AppData\Local\Programs\Python\Python310\lib\site-packages\smolagents\agents.py:1615, in CodeAgent._step_stream(self, memory_step)
#    1614 else:
# -> 1615     chat_message: ChatMessage = self.model.generate(
#    1616         input_messages,
#    1617         stop_sequences=stop_sequences,
#    1618         **additional_args,
#    1619     )
#    1620     memory_step.model_output_message = chat_message
#
# File c:\Users\niran\AppData\Local\Programs\Python\Python310\lib\site-packages\openinference\instrumentation\smolagents\_wrappers.py:313, in _ModelWrapper.__call__(self, wrapped, instance, args, kwargs)
#     312 span.set_status(trace_api.StatusCode.OK)
# --> 313 span.set_attribute(LLM_TOKEN_COUNT_PROMPT, model.last_input_token_count)
#     314 span.set_attribute(LLM_TOKEN_COUNT_COMPLETION, model.last_output_token_count)
#
# AttributeError: 'InferenceClientModel' object has no attribute 'last_input_token_count'
#
# The above exception was the direct cause of the following exception:
#
# AgentGenerationError                      Traceback (most recent call last)
# Cell In[19], line 6
#       3 search_tool = DuckDuckGoSearchTool()
#       4 agent = CodeAgent(tools=[search_tool], model=InferenceClientModel())
# ----> 6 agent.run("How many Rubik's Cubes could you fit inside the Notre Dame Cathedral?")
#
# File c:\Users\niran\AppData\Local\Programs\Python\Python310\lib\site-packages\openinference\instrumentation\smolagents\_wrappers.py:129, in _RunWrapper.__call__(self, wrapped, instance, args, kwargs)
#     111 arguments = _bind_arguments(wrapped, *args, **kwargs)
#     112 with self._tracer.start_as_current_span(
#     113     span_name,
#     114     attributes=dict(
#    (...)
#     127     ),
#     128 ) as span:
# --> 129     agent_output = wrapped(*args, **kwargs)
#     130     span.set_attribute(LLM_TOKEN_COUNT_PROMPT, agent.monitor.total_input_token_count)
#     131     span.set_attribute(LLM_TOKEN_COUNT_COMPLETION, agent.monitor.total_output_token_count)
#
# File c:\Users\niran\AppData\Local\Programs\Python\Python310\lib\site-packages\smolagents\agents.py:456, in MultiStepAgent.run(self, task, stream, reset, images, additional_args, max_steps)
#     453 run_start_time = time.time()
#     454 # Outputs are returned only at the end. We only look at the last step.
# --> 456 steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     457 assert isinstance(steps[-1], FinalAnswerStep)
#     458 output = steps[-1].output
#
# File c:\Users\niran\AppData\Local\Programs\Python\Python310\lib\site-packages\smolagents\agents.py:550, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     546             action_step.is_final_answer = True
#     548 except AgentGenerationError as e:
#     549     # Agent generation errors are not caused by a Model error but an implementation error: so we should raise them and exit.
# --> 550     raise e
#     551 except AgentError as e:
#     552     # Other AgentError types are caused by the Model, so we should log them and iterate.
#     553     action_step.error = e
#
# File c:\Users\niran\AppData\Local\Programs\Python\Python310\lib\site-packages\smolagents\agents.py:532, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     530 self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
#     531 try:
# --> 532     for output in self._step_stream(action_step):
#     533         # Yield all
#     534         yield output
#     536         if isinstance(output, ActionOutput) and output.is_final_answer:
#
# File c:\Users\niran\AppData\Local\Programs\Python\Python310\lib\site-packages\smolagents\agents.py:1638, in CodeAgent._step_stream(self, memory_step)
#    1636     memory_step.model_output = output_text
#    1637 except Exception as e:
# -> 1638     raise AgentGenerationError(f"Error in generating model output:\n{e}", self.logger) from e
#    1640 ### Parse output ###
#    1641 try:
#
# AgentGenerationError: Error in generating model output:
# 'InferenceClientModel' object has no attribute 'last_input_token_count'
